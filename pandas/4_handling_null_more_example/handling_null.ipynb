# %% [markdown]
# # Handling Null when we have empty rows represented with some large numbers or Strings (No Event)

# %%
import pandas as pd

# %%
df_weather = pd.read_csv("./weather_info.csv")

df_weather
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024           33        8.2      Rain
# 1   01-02-2024       -99999        6.0  No Event
# 2   01-03-2024           28    88888.0  No Event
# 3   01-04-2024           38    88888.0     Sunny
# 4   01-05-2024        99999    88888.0     Sunny
# 5   01-06-2024        88888        3.5  No Event
# 6   01-07-2024           25        9.1  No Event
# 7   01-08-2024       -99999   -99999.0  No Event
# 8   01-09-2024        99999    99999.0    Cloudy
# 9   01-10-2024        99999        3.6    Cloudy
# 10  01-11-2024           21        2.8     Sunny
# 11  01-12-2024           23        5.5      Rain

# %%
df_weather.describe()
# Out:
#         Temperature     Windspeed
# count     12.000000     12.000000
# mean   15754.583333  22225.225000
# std    70660.261887  58601.351495
# min   -99999.000000 -99999.000000
# 25%       22.500000      3.575000
# 50%       30.500000      7.100000
# 75%    91665.750000  88888.000000
# max    99999.000000  99999.000000

# %%
df_weather.Temperature.unique()
# Out:
# array([    33, -99999,     28,     38,  99999,  88888,     25,     21,
#            23])

# %%
df_weather["Windspeed"].unique()
# Out:
# array([ 8.2000e+00,  6.0000e+00,  8.8888e+04,  3.5000e+00,  9.1000e+00,
#        -9.9999e+04,  9.9999e+04,  3.6000e+00,  2.8000e+00,  5.5000e+00])

# %%
df_weather["Windspeed"].value_counts()
# Out:
# Windspeed
#  88888.0    3
#  8.2        1
#  6.0        1
#  3.5        1
#  9.1        1
# -99999.0    1
#  99999.0    1
#  3.6        1
#  2.8        1
#  5.5        1
# Name: count, dtype: int64

# %%
df_weather["Temperature"].value_counts()
# Out:
# Temperature
#  99999    3
# -99999    2
#  33       1
#  28       1
#  38       1
#  88888    1
#  25       1
#  21       1
#  23       1
# Name: count, dtype: int64

# %% [markdown]
# **Replace all the bad data to nan -> for proper calculations**

# %%
df_weather.replace(to_replace=[99999,-99999, 88888], value=pd.NA, inplace=True)

# %%
df_weather
# Out:
#            Day Temperature Windspeed Condition
# 0   01-01-2024          33       8.2      Rain
# 1   01-02-2024        <NA>       6.0  No Event
# 2   01-03-2024          28      <NA>  No Event
# 3   01-04-2024          38      <NA>     Sunny
# 4   01-05-2024        <NA>      <NA>     Sunny
# 5   01-06-2024        <NA>       3.5  No Event
# 6   01-07-2024          25       9.1  No Event
# 7   01-08-2024        <NA>      <NA>  No Event
# 8   01-09-2024        <NA>      <NA>    Cloudy
# 9   01-10-2024        <NA>       3.6    Cloudy
# 10  01-11-2024          21       2.8     Sunny
# 11  01-12-2024          23       5.5      Rain

# %%
df_weather.describe()
# Out:
#                Day  Temperature  Windspeed Condition
# count           12            6        7.0        12
# unique          12            6        7.0         4
# top     01-01-2024           33        8.2  No Event
# freq             1            1        1.0         5

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          12 non-null     object
#  1   Temperature  6 non-null      object
#  2   Windspeed    7 non-null      object
#  3   Condition    12 non-null     object
# dtypes: object(4)
# memory usage: 516.0+ bytes

# %%
type(df_weather["Temperature"][1])
# Out:
# pandas._libs.missing.NAType

# %%
df_weather = pd.read_csv("./weather_info.csv")

# %%
df_weather
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024           33        8.2      Rain
# 1   01-02-2024       -99999        6.0  No Event
# 2   01-03-2024           28    88888.0  No Event
# 3   01-04-2024           38    88888.0     Sunny
# 4   01-05-2024        99999    88888.0     Sunny
# 5   01-06-2024        88888        3.5  No Event
# 6   01-07-2024           25        9.1  No Event
# 7   01-08-2024       -99999   -99999.0  No Event
# 8   01-09-2024        99999    99999.0    Cloudy
# 9   01-10-2024        99999        3.6    Cloudy
# 10  01-11-2024           21        2.8     Sunny
# 11  01-12-2024           23        5.5      Rain

# %%
import numpy as np

# %%
df_weather.replace(to_replace=[-99999,88888,99999], value=np.nan, inplace=True)

# %%
df_weather
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024         33.0        8.2      Rain
# 1   01-02-2024          NaN        6.0  No Event
# 2   01-03-2024         28.0        NaN  No Event
# 3   01-04-2024         38.0        NaN     Sunny
# 4   01-05-2024          NaN        NaN     Sunny
# 5   01-06-2024          NaN        3.5  No Event
# 6   01-07-2024         25.0        9.1  No Event
# 7   01-08-2024          NaN        NaN  No Event
# 8   01-09-2024          NaN        NaN    Cloudy
# 9   01-10-2024          NaN        3.6    Cloudy
# 10  01-11-2024         21.0        2.8     Sunny
# 11  01-12-2024         23.0        5.5      Rain

# %%
df_weather = pd.read_csv("./weather_info.csv")

# %%
df_weather
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024           33        8.2      Rain
# 1   01-02-2024       -99999        6.0  No Event
# 2   01-03-2024           28    88888.0  No Event
# 3   01-04-2024           38    88888.0     Sunny
# 4   01-05-2024        99999    88888.0     Sunny
# 5   01-06-2024        88888        3.5  No Event
# 6   01-07-2024           25        9.1  No Event
# 7   01-08-2024       -99999   -99999.0  No Event
# 8   01-09-2024        99999    99999.0    Cloudy
# 9   01-10-2024        99999        3.6    Cloudy
# 10  01-11-2024           21        2.8     Sunny
# 11  01-12-2024           23        5.5      Rain

# %%
df_weather.replace(to_replace={
    "Temperature":[88888,-99999, 99999],
    "Windspeed":[88888,-99999, 99999],
    "Condition":"No Event"
}, value= np.nan)
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024         33.0        8.2      Rain
# 1   01-02-2024          NaN        6.0       NaN
# 2   01-03-2024         28.0        NaN       NaN
# 3   01-04-2024         38.0        NaN     Sunny
# 4   01-05-2024          NaN        NaN     Sunny
# 5   01-06-2024          NaN        3.5       NaN
# 6   01-07-2024         25.0        9.1       NaN
# 7   01-08-2024          NaN        NaN       NaN
# 8   01-09-2024          NaN        NaN    Cloudy
# 9   01-10-2024          NaN        3.6    Cloudy
# 10  01-11-2024         21.0        2.8     Sunny
# 11  01-12-2024         23.0        5.5      Rain

# %%
df_weather
# Out:
#            Day  Temperature  Windspeed Condition
# 0   01-01-2024           33        8.2      Rain
# 1   01-02-2024       -99999        6.0  No Event
# 2   01-03-2024           28    88888.0  No Event
# 3   01-04-2024           38    88888.0     Sunny
# 4   01-05-2024        99999    88888.0     Sunny
# 5   01-06-2024        88888        3.5  No Event
# 6   01-07-2024           25        9.1  No Event
# 7   01-08-2024       -99999   -99999.0  No Event
# 8   01-09-2024        99999    99999.0    Cloudy
# 9   01-10-2024        99999        3.6    Cloudy
# 10  01-11-2024           21        2.8     Sunny
# 11  01-12-2024           23        5.5      Rain

# %%
df_weather.replace({
    99999:np.nan,
    88888:np.nan,
    -99999:np.nan,
    "No Event":"Not Found"
    
})
# Out:
#            Day  Temperature  Windspeed  Condition
# 0   01-01-2024         33.0        8.2       Rain
# 1   01-02-2024          NaN        6.0  Not Found
# 2   01-03-2024         28.0        NaN  Not Found
# 3   01-04-2024         38.0        NaN      Sunny
# 4   01-05-2024          NaN        NaN      Sunny
# 5   01-06-2024          NaN        3.5  Not Found
# 6   01-07-2024         25.0        9.1  Not Found
# 7   01-08-2024          NaN        NaN  Not Found
# 8   01-09-2024          NaN        NaN     Cloudy
# 9   01-10-2024          NaN        3.6     Cloudy
# 10  01-11-2024         21.0        2.8      Sunny
# 11  01-12-2024         23.0        5.5       Rain

# %%
df_scores = pd.DataFrame({
   "name":["Shurti","Rohan","Pratik","Ashish","Abdul","Rohini"],
   "Grade":["excellent","average","poor","good","excellent","poor"]
})

df_scores
# Out:
#      name      Grade
# 0  Shurti  excellent
# 1   Rohan    average
# 2  Pratik       poor
# 3  Ashish       good
# 4   Abdul  excellent
# 5  Rohini       poor

# %%
# Replace Grade String To Grades (A,B,C)
# excellent, good, average, poor
# A, B, C, D
df_scores.replace({
    "excellent":"A", 
    "good":"B",
    "average":"C",
    "poor":"D"
})
# Out:
#      name Grade
# 0  Shurti     A
# 1   Rohan     C
# 2  Pratik     D
# 3  Ashish     B
# 4   Abdul     A
# 5  Rohini     D

# %%
df_scores
# Out:
#      name      Grade
# 0  Shurti  excellent
# 1   Rohan    average
# 2  Pratik       poor
# 3  Ashish       good
# 4   Abdul  excellent
# 5  Rohini       poor

# %%
df_scores.replace(["excellent","good","average","poor"],["A","B","C","D"])
# Out:
#      name Grade
# 0  Shurti     A
# 1   Rohan     C
# 2  Pratik     D
# 3  Ashish     B
# 4   Abdul     A
# 5  Rohini     D
